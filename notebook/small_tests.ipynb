# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

from stochastic_graph import StochasticGraph
from preprocessing import bfReach, detReach, bfArcFlags, detArcFlags
from SOTA import StandardSOTASolver, SingleIterationSOTASolver
from deterministic_algorithms import Dijkstra
from utilities import TestFunctions, Utils

import warnings
warnings.filterwarnings("ignore", message="KMeans is known to have a memory leak")

sys.path.append(os.path.abspath("../graph"))

from Grid_network_and_Gamma_distribution import Matrix

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
graph = Utils.load_object("./instances/graphs/5x5-1.pkl")

node_s = 20
node_d = 4
time_budget = 150

TestFunctions.run_standard_sota(graph, node_d, time_budget)
TestFunctions.run_single_iteration_sota(graph, node_d, time_budget)
# Out:
# Object loaded from ./instances/graphs/5x5-1.pkl
# Solving SOTA with Successive Approximations... (Discretizing by Delta t = 5.22585403020512)
# Convergence reached in 9 iterations with delta 4.017897086902547e-15
# Policy computed on 48.9191 seconds
# policy last column:
# [ 1  6  7  8 -1  6  7  8  3  8 11  6 13 14 19 16 17 12 13 18 15 22 17 18
#  19]
# sota last column:
# [0.97608212 1.         1.         1.         1.         1.
#  1.         1.         1.         1.         0.54853361 0.92700263
#  0.95251614 0.95712012 1.         0.286532   0.27936162 0.85839493
#  1.         1.         0.24669076 0.74689789 0.68635623 0.71352985
#  0.94649414]
# Solving SOTA with Single Iteration... (Discretizing by Delta t = 5.22585403020512)
# SOTA computation with Single Iteration completed.
# Policy computed on 10.5929 seconds
# policy last column:
# [ 1  6  3  8 -1  6  7  8  3  4 15 12 13 14  9 16 15 12 13 14 15 22 23 18
#  19]
# sota last column:
# ...

# %%
graph = Utils.load_object("./instances/graphs/5x5-1.pkl")

node_s = 20
node_d = 4
time_budget = 150

TestFunctions.run_standard_sota(graph, node_d, time_budget, delta_t=1)
TestFunctions.run_single_iteration_sota(graph, node_d, time_budget, delta_t=1)
;
# Out:
# Object loaded from ./instances/graphs/5x5-1.pkl
# Solving SOTA with Successive Approximations... (Discretizing by Delta t = 1)
# Convergence reached in 9 iterations with delta 7.517907640964869e-17
# Policy computed on 1501.8721 seconds
# policy last column:
# [ 1  2  3  8 -1  6  7  8  9 14 15 12 13  8 13 16 17 12 13 14 15 22 23 18
#  19]
# sota last column:
# [0.99999983 1.         1.         1.         1.         0.60221554
#  1.         1.         1.         1.         0.75508683 0.99998911
#  1.         1.         1.         0.99976489 1.         1.
#  1.         1.         0.49634175 0.04282993 0.47505896 0.99999993
#  0.99997642]
# Solving SOTA with Single Iteration... (Discretizing by Delta t = 1)
# SOTA computation with Single Iteration completed.
# Policy computed on 161.3444 seconds
# policy last column:
# [ 1  2  3  8 -1  6  7  8  9 14 15 12 13  8 13 16 17 12 13 14 15 22 23 18
#  19]
# sota last column:
# [9.99987505e-01 1.00000000e+00 1.00000000e+00 1.00000000e+00
# ...

# %%
graph = graph = Utils.load_object("./instances/graphs/10x10-1.pkl")

TestFunctions.run_reach(graph, 18, 72, 300, print_pruned_graph=True, show_edge_labels=False)
# Out:
# Object loaded from ./instances/graphs/10x10-1.pkl
# Reach values computeds...
# Pruning nodes...Reach computed and pruned in 0.4358 seconds. Pruned 39 nodes: {0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 13, 20, 21, 22, 23, 30, 31, 32, 33, 40, 57, 67, 68, 75, 76, 77, 78, 79, 86, 87, 88, 89, 90, 91, 96, 97, 98, 99}
# Graph after reach pruning with s=18, d=72
# ------- STANDARD SOTA on Reach-pruned graph ---------
#
# Solving SOTA with Successive Approximations... (Discretizing by Delta t = 5.2878640421407725)
# Computing SOTA..., iteration number: 1, delta=inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[130], line 3
#       1 graph = graph = Utils.load_object("./instances/graphs/10x10-1.pkl")
# ----> 3 TestFunctions.run_reach(graph, 18, 72, 300, print_pruned_graph=True, show_edge_labels=False)
#
# ...
