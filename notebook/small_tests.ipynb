# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

from stochastic_graph import StochasticGraph
from preprocessing import bfReach, detReach, bfArcFlags, detArcFlags
from SOTA import StandardSOTASolver, SingleIterationSOTASolver
from deterministic_algorithms import Dijkstra
from utilities import TestFunctions, Utils

import warnings
warnings.filterwarnings("ignore", message="KMeans is known to have a memory leak")

sys.path.append(os.path.abspath("../graph"))

from Grid_network_and_Gamma_distribution import Matrix

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
graph = Utils.load_object("./instances/graphs/5x5-1.pkl")

s = StandardSOTASolver(graph, 23, 300)
s.solve()

TestFunctions.paths_comparison_run(graph, )
# Out:
# Object loaded from ./instances/graphs/20x20-1.pkl
# Partitioning of the graph in 5 regions executed in 0.0340 seconds!
# Arcflags computed!...
# [ArcFlags] Pruned 153 edges for destination 146 (region 0).
# Arcflags computed and pruned in 3.2287 seconds
# Graph after arcflags pruning:
# c:\ProgramData\miniconda3\envs\myenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# ------- STANDARD SOTA on Arcflags-pruned graph ---------
#
# Solving SOTA with Successive Approximations... (Discretizing by Delta t = 5.003731520942551)
# Computing SOTA..., iteration number: 1, delta=inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 3
#       1 graph = Utils.load_object("./instances/graphs/20x20-1.pkl")
# ----> 3 TestFunctions.run_arcflags(graph, 146, 100, print_pruned_graph=True, show_edge_labels=False, show_node_labels=False)
#
# File c:\SAMU\UNITO\MAGISTRALE\internship+tesi\codice\SOTA solver\src\utilities.py:24, in run_arcflags(graph, destination_node, time_budget, eps, max_iter, delta_t, print_pruned_graph, show_edge_labels, show_node_labels, print_results, print_summary)
#      22 # changing discretization variable if needed
#      23 if delta_t is not None:
# ---> 24     s.set_min_edge(delta_t)
#      26 # solving and timing
#      27 start = time.time()
#
# File c:\SAMU\UNITO\MAGISTRALE\internship+tesi\codice\SOTA solver\src\utilities.py:28, in TestFunctions.run_standard_sota(graph, destination_node, time_budget, eps, max_iter, delta_t, print_results)
#      26 # solving and timing
#      27 start = time.time()
# ---> 28 s.solve(eps=eps, max_iter=max_iter)
#      29 end = time.time()
#      31 # printing results
#
# File c:\SAMU\UNITO\MAGISTRALE\internship+tesi\codice\SOTA solver\src\SOTA.py:273, in StandardSOTASolver.solve(self, eps, max_iter)
#     270 for i in range(max_iter):
#     271     print(f"\rComputing SOTA..., iteration number: {i+1}, delta={delta}", end="")
# --> 273     delta = self.update_sota()
#     274     if delta < eps:
#     275         # convergence
#     276         print(f"\rConvergence reached in {i+1} iterations with delta {delta}")
#
# File c:\SAMU\UNITO\MAGISTRALE\internship+tesi\codice\SOTA solver\src\SOTA.py:253, in StandardSOTASolver.update_sota(self)
#     250 old_matrix = self.sota_matrix.copy()  # copy of the current SOTA matrix
#     252 for node in range(self.num_nodes):
# --> 253     self.update_node(node)
#     255 # compute the norm of the difference between old and new matrix
#     256 norm = np.sum(np.abs(self.sota_matrix - old_matrix))
#
# File c:\SAMU\UNITO\MAGISTRALE\internship+tesi\codice\SOTA solver\src\SOTA.py:233, in StandardSOTASolver.update_node(self, node_i)
#     230 successors = self.graph.get_successor_nodes(node_i)  # finds the successors of node_i
#     232 for j in successors:
# --> 233     conv = self.compute_convolution(node_i, j, t)
#     234     if conv > max_val:
#     235         max_val = conv
#
# File c:\SAMU\UNITO\MAGISTRALE\internship+tesi\codice\SOTA solver\src\SOTA.py:210, in StandardSOTASolver.compute_convolution(self, node_i, node_j, t)
#     209 def compute_convolution(self, node_i, node_j, t):
# --> 210     return super().compute_convolution(node_i, node_j, t, self.sota_matrix)
#
# File c:\SAMU\UNITO\MAGISTRALE\internship+tesi\codice\SOTA solver\src\SOTA.py:136, in SOTA.compute_convolution(self, node_i, node_j, t, matrix)
#     126 for s_step in range(1, self.num_cols + 1):
#     127     # right endpoint rule
#     128     #s_time = s_step * self.min_edge  # corresponding real time
#    (...)    132
#     133     # midpoint rule
#     134     s_time = (s_step - 0.5) * self.min_edge
# --> 136     p = self.compute_density(node_i, node_j, s_time)
#     138     # u_j(t-omega)
#     139     matrix_col = int((t - s_time) / self.min_edge)
#
# File c:\SAMU\UNITO\MAGISTRALE\internship+tesi\codice\SOTA solver\src\SOTA.py:106, in SOTA.compute_density(self, node_i, node_j, s)
#     104 # we use the logaritmic function
#     105 try:
# --> 106     log_G = gamma.logpdf(s, a=alpha, scale=scale)
#     107     G = np.exp(log_G)
#     108 except OverflowError:
#     109     # if we still have overflow, we return 0.0, as the density is almost null
#
# File c:\ProgramData\miniconda3\envs\myenv\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2112, in rv_continuous.logpdf(self, x, *args, **kwds)
#    2110 output = empty(shape(cond), dtyp)
#    2111 output.fill(-inf)
# -> 2112 putmask(output, (1-cond0)+np.isnan(x), self.badvalue)
#    2113 if np.any(cond):
#    2114     goodargs = argsreduce(cond, *((x,)+args+(scale,)))
#
# KeyboardInterrupt:
