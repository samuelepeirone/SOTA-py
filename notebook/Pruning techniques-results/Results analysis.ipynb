# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Computation times and speedups
# ### 5x5 network

# %%
df = pd.read_csv('tables/5x5.csv', index_col=0)
plt.figure(figsize=(10, 6))

for col in df.columns:
    plt.plot(df.index, df[col], label=col)

plt.title('Computation time for each algorithm in 5x5 grid network')
plt.xlabel('time budget')
plt.ylabel('computation time')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
df = pd.read_csv('tables/5x5-speedup.csv', index_col=0)

colors = ['#2ca02c', '#d62728', '#9467bd', '#8c564b']
plt.figure(figsize=(10, 6))

for i, col in enumerate(df.columns):
    color = colors[i % len(colors)]
    plt.plot(df.index, df[col], label=col, color=color)

plt.title('Speedups for each algorithm in 5x5 grid network')
plt.xlabel('time budget')
plt.ylabel('speedup')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### 6x6 network

# %%
df = pd.read_csv('tables/6x6.csv', index_col=0)
plt.figure(figsize=(10, 6))

for col in df.columns:
    plt.plot(df.index, df[col], label=col)

plt.title('Computation time for each algorithm in 6x6 grid network')
plt.xlabel('time budget')
plt.ylabel('computation time')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
df = pd.read_csv('tables/6x6-speedup.csv', index_col=0)

colors = ['#2ca02c', '#d62728', '#9467bd', '#8c564b']
plt.figure(figsize=(10, 6))

for i, col in enumerate(df.columns):
    color = colors[i % len(colors)]
    plt.plot(df.index, df[col], label=col, color=color)

plt.title('Speedups for each algorithm in 6x6 grid network')
plt.xlabel('time budget')
plt.ylabel('speedup')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### 7x7 network

# %%
df = pd.read_csv('tables/7x7.csv', index_col=0)
plt.figure(figsize=(10, 6))

for col in df.columns:
    plt.plot(df.index, df[col], label=col)

plt.title('Computation time for each algorithm in 7x7 grid network')
plt.xlabel('time budget')
plt.ylabel('computation time')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
df = pd.read_csv('tables/7x7-speedup.csv', index_col=0)

colors = ['#2ca02c', '#d62728', '#9467bd', '#8c564b']
plt.figure(figsize=(10, 6))

for i, col in enumerate(df.columns):
    color = colors[i % len(colors)]
    plt.plot(df.index, df[col], label=col, color=color)

plt.title('Speedups for each algorithm in 7x7 grid network')
plt.xlabel('time budget')
plt.ylabel('speedup')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()
